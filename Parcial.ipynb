# %% [markdown]
# <a href="https://colab.research.google.com/github/LaraV15/Pr-ctica/blob/main/Parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Forma 1
cant = 5
for i in range(cant): #i va a ir del 0 al 4
  print("*"*(cant-i))
# Out:
# *****
# ****
# ***
# **
# *

# %%
#Forma 2
cant = 5
for i in reversed(range(cant)): #i va a ir de 4 a 0
  print("*"*(i+1))
# Out:
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
precio = float(input("Ingrese el precio del producto: "))

reintegro = precio*0.3

print("Recibira un reintegreo de: $", reintegro,)
# Out:
# Ingrese el precio del producto: 100
# Recibira un reintegreo de: $ 30.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
edad = int(input("Ingrese su edad en números: "))

if edad < 18:
  print("Pertenece al segmento niños y adolescentes")
elif edad >= 18 and edad <=25:
      print("Pertenece al segmento jóvenes")
elif edad > 25 and edad <=65:
      print("Pertenece al segmento adultos")
else:
  print("Pertenece al segmento jubilados ")
# Out:
# Ingrese su edad en números: 70
# Pertenece al segmento jubilados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
estudiantes = {}
cont = 1
while cont != 0:
  legajo = int(input("Ingrese el legajo del estudiante, 0 para terminar: "))
  if legajo != 0:
    nota = input("Ingrese la nota del estudiante: ")
    estudiantes[str(legajo)] = nota
  else:
    cont = 0

print(estudiantes)
# Out:
# Ingrese el legajo del estudiante, 0 para terminar: 45411
# Ingrese la nota del estudiante: 10
# Ingrese el legajo del estudiante, 0 para terminar: 55448
# Ingrese la nota del estudiante: 9
# Ingrese el legajo del estudiante, 0 para terminar: 511118
# Ingrese la nota del estudiante: 8
# Ingrese el legajo del estudiante, 0 para terminar: 0
# {'45411': '10', '55448': '9', '511118': '8'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
base = {"LaraV15": 123456, "Carla123": 455465}
opc = "a"
ingreso = 0 #esta variable la voy a usar para saber si la persona inició sesión

while opc != "s":
  print("¿Qué desea hacer? \n Ingrese i para ingresar \n Ingrese r para registrarse \n Ingrese c para cerrar sesión \n Ingrese s para salir")
  opc = input().lower()

  if opc == "i":
    us = input("Ingrese su usuario: ")
    if us in base:
      contra = input("Ingrese su contraseña")
      if contra in base.values():
        ingreso = 1 #esta variable la voy a usar para saber que inició sesión
        continue
      else: 
        print("La contraseña ingresada es incorrecta, intente nuevamente")
    else: 
      print("El usuario ingresado es incorrecto, intente nuevamente")
      

  if opc == "r":  
    usn = input("Ingrese su nuevo usario: ")
    while usn in base:
      usnuevo = input("Ese usario ya existe, intente nuevamente: ")
    contranueva = input("Ingrese su contraseña: ")
    base[str(usnuevo)]=contranueva
    print("Su ususario ha sido creado correctamente.")
    ingreso = 1

  if opc == "c":
    if ingreso == 1:
      sino = str(input("¿Esta seguro que desea cerrar sesión y salir? Responder si o no")).lower()
      if sino == "si":
        opc == "s"
    else:
      print("Usted no ha iniciado sesión")
  
# Falta el apartado e
# Out:
# ¿Qué desea hacer?
#  Ingrese i para ingresar
#  Ingrese r para registrarse
#  Ingrese c para cerrar sesión
#  Ingrese s para salir
# S

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
datos={'Lara': '1234', 'Denise': '456', 'Ariana': 'ari123'} #key: nombre de usuario, value: contraseña
print("¿Qúe desea hacer?")
print(" 1 - Ingresar, ingrese i")
print(" 2 - Registrarse, ingrese r")
print(" 3 - Cerrar sesión, ingrese c")
print(" 4 - Cambiar contraseña, ingrese n")
print(" 5 - Salir ingrese s")
opcion=input().lower()

#verificar si la opción ingresada es correcta

ingreso=0 #si están variables pasa a 1, quiere decir que el usario inició sesión o se registro y puede cerrar sesión

while opcion != "s" :
  
  
  if opcion == "i" :
    ingreso=1
    usuario = input("Ingrese su usario: ")
    if usuario in datos:
      contraseña = input("Ingrese su contrseña: ")
      for i in range(2):
        if contraseña != datos[usuario]:
          contraseña = input("Contraseñna inválida, intente nuevamente: ")
      if datos[usuario]==contraseña:
        print("Usted ha iniciado sesión correctamente")
      else:
        print("Su usuario ha sido bloqueado")
    else:
      print("Ususario inválido, intente nuevamente.")
  
  if opcion == "r":
    ingreso=1
    usuario = input("Ingrese el nombre de usario: ")
    while usuario in datos.keys():
      usuario = input("Ese nombre de usuario ya se utiliza, intente nuevamente: ")
    
    contraseña = input("Ingrese la contraseña: ")
    datos[usuario] = contraseña
  
  if opcion == "c":
    if ingreso==1:
      decisión = input("¿Está seguro que desea cerrar sesión? SI/NO").upper()
    else: 
      print("No es posible cerrar sesión porque usted no ha iniciado sesión o no sea resgistrado")
    
  if opcion == "n":
    usuario = input("Ingrese su usario: ")
    if usuario in datos:
      contraseña=input("Ingrese su nueva contraseña")
      datos[usuario]=contraseña
    else:
      usuario = input("Usario inválido, itente nuevamente: ")
    

  opcion = input("¿Qúe desea hacer? \n 1 - Ingresar, ingrese i \n 2 - Registrarse, ingrese r \n 3 - Cerrar sesión, ingrese c \n 4 - Cambiar contraseña, ingrese n \n 5 - Salir ingrese s").lower()
   
print(datos)
# Out:
# ¿Qúe desea hacer?
#  1 - Ingresar, ingrese i
#  2 - Registrarse, ingrese r
#  3 - Cerrar sesión, ingrese c
#  4 - Cambiar contraseña, ingrese n
#  5 - Salir ingrese s
# i
# Ingrese su usario: Lara
# Ingrese su contrseña: 12345
# Contraseñna inválida, intente nuevamente: 445
# Contraseñna inválida, intente nuevamente: 555
# Su usuario ha sido bloqueado
# ¿Qúe desea hacer?
#  1 - Ingresar, ingrese i
#  2 - Registrarse, ingrese r
#  3 - Cerrar sesión, ingrese c
#  4 - Cambiar contraseña, ingrese n
#  5 - Salir ingrese ss
# {'Lara': '1234', 'Denise': '456', 'Ariana': 'ari123'}
